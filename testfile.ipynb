# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
import pprint as pp
import scraping_EN

# %%
nlp = en_core_web_sm.load()

# %%
article = "Russian President Vladimir Putin ordered troops into eastern Ukraine on Feb. 21, 2022. The invasion could lead to the biggest armed conflict in Europe since World War II, Western leaders warn. But amid the mounting tensions, public opinion polls in Russia show that support for Putin is rising. The rally ‘round the flag effect of supporting political leadership during an international crisis will likely be short-lived. Historical data shows that diversionary wars — fighting abroad to draw attention away from problems at home — have rarely worked for Putin. Daring and expensive military adventures will, over time, decrease the Kremlin’s popularity, history also tells us. As a scholar of Russia and public opinion, I know that war ultimately requires an enormous amount of public goodwill and support for a political leader — far more than a brief spike in popularity can ensure."

# %%
article
# Out:
# 'Russian President Vladimir Putin ordered troops into eastern Ukraine on Feb. 21, 2022. The invasion could lead to the biggest armed conflict in Europe since World War II, Western leaders warn. But amid the mounting tensions, public opinion polls in Russia show that support for Putin is rising. The rally ‘round the flag effect of supporting political leadership during an international crisis will likely be short-lived. Historical data shows that diversionary wars — fighting abroad to draw attention away from problems at home — have rarely worked for Putin. Daring and expensive military adventures will, over time, decrease the Kremlin’s popularity, history also tells us. As a scholar of Russia and public opinion, I know that war ultimately requires an enormous amount of public goodwill and support for a political leader — far more than a brief spike in popularity can ensure.'

# %%
doc = nlp(article)
print([(X.text, X.label_) for X in doc.ents])
# Out:
# [('Russian', 'NORP'), ('Vladimir Putin', 'PERSON'), ('Ukraine', 'GPE'), ('Feb. 21, 2022', 'DATE'), ('Europe', 'LOC'), ('World War II', 'EVENT'), ('Russia', 'GPE'), ('Putin', 'PERSON'), ('Putin', 'PERSON'), ('Kremlin', 'ORG'), ('Russia', 'GPE')]

# %%
pp.pprint([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [(Russian, 'B', 'NORP'),
#  (President, 'O', ''),
#  (Vladimir, 'B', 'PERSON'),
#  (Putin, 'I', 'PERSON'),
#  (ordered, 'O', ''),
#  (troops, 'O', ''),
#  (into, 'O', ''),
#  (eastern, 'O', ''),
#  (Ukraine, 'B', 'GPE'),
#  (on, 'O', ''),
#  (Feb., 'B', 'DATE'),
#  (21, 'I', 'DATE'),
#  (,, 'I', 'DATE'),
#  (2022, 'I', 'DATE'),
#  (., 'O', ''),
#  (The, 'O', ''),
#  (invasion, 'O', ''),
#  (could, 'O', ''),
#  (lead, 'O', ''),
#  (to, 'O', ''),
#  (the, 'O', ''),
#  (biggest, 'O', ''),
#  (armed, 'O', ''),
#  (conflict, 'O', ''),
#  (in, 'O', ''),
#  (Europe, 'B', 'LOC'),
#  (since, 'O', ''),
#  (World, 'B', 'EVENT'),
#  (War, 'I', 'EVENT'),
#  (II, 'I', 'EVENT'),
#  (,, 'O', ''),
#  (Western, 'O', ''),
#  (leaders, 'O', ''),
#  (warn, 'O', ''),
#  (., 'O', ''),
#  (But, 'O', ''),
#  (amid, 'O', ''),
#  (the, 'O', ''),
#  (mounting, 'O', ''),
#  (tensions, 'O', ''),
#  (,, 'O', ''),
#  (public, 'O', ''),
#  (opinion, 'O', ''),
#  (polls, 'O', ''),
#  (in, 'O', ''),
#  (Russia, 'B', 'GPE'),
#  (show, 'O', ''),
#  (that, 'O', ''),
#  (support, 'O', ''),
#  (for, 'O', ''),
#  (Putin, 'B', 'PERSON'),
#  (is, 'O', ''),
#  (rising, 'O', ''),
#  (., 'O', ''),
#  (The, 'O', ''),
#  (rally, 'O', ''),
#  (‘, 'O', ''),
#  (round, 'O', ''),
#  (the, 'O', ''),
#  (flag, 'O', ''),
#  (effect, 'O', ''),
#  (of, 'O', ''),
#  (supporting, 'O', ''),
#  (political, 'O', ''),
#  (leadership, 'O', ''),
#  (during, 'O', ''),
#  (an, 'O', ''),
#  (international, 'O', ''),
#  (crisis, 'O', ''),
#  (will, 'O', ''),
#  (likely, 'O', ''),
#  (be, 'O', ''),
#  (short, 'O', ''),
#  (-, 'O', ''),
#  (lived, 'O', ''),
#  (., 'O', ''),
#  (Historical, 'O', ''),
#  (data, 'O', ''),
#  (shows, 'O', ''),
#  (that, 'O', ''),
#  (diversionary, 'O', ''),
#  (wars, 'O', ''),
#  (—, 'O', ''),
#  (fighting, 'O', ''),
#  (abroad, 'O', ''),
#  (to, 'O', ''),
#  (draw, 'O', ''),
#  (attention, 'O', ''),
#  (away, 'O', ''),
#  (from, 'O', ''),
#  (problems, 'O', ''),
#  (at, 'O', ''),
#  (home, 'O', ''),
#  (—, 'O', ''),
#  (have, 'O', ''),
#  (rarely, 'O', ''),
#  (worked, 'O', ''),
#  (for, 'O', ''),
#  (Putin, 'B', 'PERSON'),
#  (., 'O', ''),
#  (Daring, 'O', ''),
#  (and, 'O', ''),
#  (expensive, 'O', ''),
#  (military, 'O', ''),
#  (adventures, 'O', ''),
#  (will, 'O', ''),
#  (,, 'O', ''),
#  (over, 'O', ''),
#  (time, 'O', ''),
#  (,, 'O', ''),
#  (decrease, 'O', ''),
#  (the, 'O', ''),
#  (Kremlin, 'B', 'ORG'),
#  (’s, 'O', ''),
#  (popularity, 'O', ''),
#  (,, 'O', ''),
#  (history, 'O', ''),
#  (also, 'O', ''),
#  (tells, 'O', ''),
#  (us, 'O', ''),
#  (., 'O', ''),
#  (As, 'O', ''),
#  (a, 'O', ''),
#  (scholar, 'O', ''),
#  (of, 'O', ''),
#  (Russia, 'B', 'GPE'),
#  (and, 'O', ''),
#  (public, 'O', ''),
#  (opinion, 'O', ''),
#  (,, 'O', ''),
#  (I, 'O', ''),
#  (know, 'O', ''),
#  (that, 'O', ''),
#  (war, 'O', ''),
#  (ultimately, 'O', ''),
#  (requires, 'O', ''),
#  (an, 'O', ''),
#  (enormous, 'O', ''),
#  (amount, 'O', ''),
#  (of, 'O', ''),
#  (public, 'O', ''),
#  (goodwill, 'O', ''),
#  (and, 'O', ''),
#  (support, 'O', ''),
#  (for, 'O', ''),
#  (a, 'O', ''),
#  (political, 'O', ''),
#  (leader, 'O', ''),
#  (—, 'O', ''),
#  (far, 'O', ''),
#  (more, 'O', ''),
#  (than, 'O', ''),
#  (a, 'O', ''),
#  (brief, 'O', ''),
#  (spike, 'O', ''),
#  (in, 'O', ''),
#  (popularity, 'O', ''),
#  (can, 'O', ''),
#  (ensure, 'O', ''),
#  (., 'O', '')]

# %%
url = 'https://theconversation.com/putins-public-approval-is-soaring-during-the-russia-ukraine-crisis-but-its-unlikely-to-last-177302'
article = scraping_EN.get_articles_theconversation(url)
article_nlp = nlp(article['content'])

# %%
len(article_nlp.ents)
# Out:
# 151

# %%
labels = [x.label_ for x in article_nlp.ents]
Counter(labels)
# Out:
# Counter({'NORP': 32,
#          'PERSON': 17,
#          'GPE': 49,
#          'DATE': 20,
#          'LOC': 1,
#          'EVENT': 1,
#          'ORG': 10,
#          'PERCENT': 12,
#          'FAC': 2,
#          'ORDINAL': 1,
#          'WORK_OF_ART': 1,
#          'CARDINAL': 5})

# %%
items = [x.text for x in article_nlp.ents]
Counter(items).most_common(10)
# Out:
# [('Russia', 16),
#  ('Putin', 15),
#  ('Ukraine', 14),
#  ('Russian', 13),
#  ('Russians', 12),
#  ('Ukrainian', 4),
#  ('Donbas', 4),
#  ('Kremlin', 3),
#  ('Feb. 22', 3),
#  ('two', 3)]

# %%
sentences = [x for x in article_nlp.sents]
print(sentences[20])
# Out:
#  “Every indication is that Russia is continuing to plan for a full-scale attack of Ukraine,” NATO Secretary-General Jens Stoltenberg said on Feb. 22.

# %%
displacy.render(article_nlp, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vladimir Putin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  ordered troops into eastern
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ukraine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Feb. 21, 2022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The invasion could lead to the biggest armed conflict in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Europe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  since
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World War II
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
# , Western leaders warn.  But amid the mounting tensions, public opinion polls in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  show that support for
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Putin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is rising.  The rally ‘round the flag effect of supporting political leadership during an international crisis will likely be short-lived.  Historical data shows that diversionary wars — fighting abroad to draw attention away from problems at home — have rarely worked for
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Putin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .  Daring and expensive military adventures will, over time, decrease the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kremlin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s popularity, history also tells us.  As a scholar of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and public opinion, I know that war ultimately requires an enormous amount of public goodwill and support for a political leader — far more than a brief spike in popularity can ensure.
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ’s military buildup along the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ukrainian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  border over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last few months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  coincides with a steady rise in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Putin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ’s popularity.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Approximately 69%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russians
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  now approve of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Putin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , compared to the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     61%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  who approved of him in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     August 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , according to
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  polling agency
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Levada Center
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# . And
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     29%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radi
